# %%
pip install alpha_vantage
# Out:
# ...
#   Using cached alpha_vantage-2.3.1-py3-none-any.whl (31 kB)
# ...
# Processing /Users/paulbrian/Library/Caches/pip/wheels/ec/4c/b4/49b28ff87279c75374ed0b9bc590808ebc5859bbca0adc641c/aiohttp-3.7.3-py3-none-any.whl
# ...
#   Using cached multidict-5.1.0.tar.gz (53 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Using cached async_timeout-3.0.1-py3-none-any.whl (8.2 kB)
# ...
#   Using cached yarl-1.6.3.tar.gz (176 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Created wheel for multidict: filename=multidict-5.1.0-cp38-cp38-macosx_10_9_x86_64.whl size=48605 sha256=592742ff9f4948bfe8c519f9bbef3a71c40163ce1c95a00ad285669fc155703d
#   Stored in directory: /Users/paulbrian/Library/Caches/pip/wheels/72/97/bc/5bffee542d18b454f73bd1a593cd104de3c46a50e4f2946728
# ...

# %%
import pandas
from alpha_vantage.fundamentaldata import FundamentalData
key = "3l9KFA1P2MWBQ5WS"
fd = FundamentalData(key, output_format = "pandas")
data_company_overview_apple = fd.get_company_overview("AAPL")
data_company_overview[0].T
# Out:
#                                                                           NaN
# Symbol                                                                   AAPL
# AssetType                                                        Common Stock
# Name                                                                Apple Inc
# Description                 Apple Inc. designs, manufactures, and markets ...
# Exchange                                                               NASDAQ
# Currency                                                                  USD
# Country                                                                   USA
# Sector                                                             Technology
# Industry                                                 Consumer Electronics
# Address                     One Apple Park Way, Cupertino, CA, United Stat...
# FullTimeEmployees                                                      147000
# ...

# %%
data_company_overview_AMZN = fd.get_company_overview("AMZN")
data_company_overview_AMZN[0].T
# Out:
#                                                                           NaN
# Symbol                                                                   AMZN
# AssetType                                                        Common Stock
# Name                                                          Amazon.com, Inc
# Description                 Amazon.com, Inc. engages in the retail sale of...
# Exchange                                                               NASDAQ
# Currency                                                                  USD
# Country                                                                   USA
# Sector                                                      Consumer Cyclical
# Industry                                                      Internet Retail
# Address                     410 Terry Avenue North, Seattle, WA, United St...
# FullTimeEmployees                                                     1298000
# ...

# %%
data_company_overview_NFLX = fd.get_company_overview("NFLX")
data_company_overview_NFLX[0].T
# Out:
#                                                                           NaN
# Symbol                                                                   NFLX
# AssetType                                                        Common Stock
# Name                                                             Netflix, Inc
# Description                 Netflix, Inc. provides entertainment services....
# Exchange                                                               NASDAQ
# Currency                                                                  USD
# Country                                                                   USA
# Sector                                                 Communication Services
# Industry                                                        Entertainment
# Address                     100 Winchester Circle, Los Gatos, CA, United S...
# FullTimeEmployees                                                        9400
# ...

# %%
data_company_overview_GOOGL = fd.get_company_overview("GOOGL")
data_company_overview_GOOGL[0].T
# Out:
#                                                                           NaN
# Symbol                                                                  GOOGL
# AssetType                                                        Common Stock
# Name                                                             Alphabet Inc
# Description                 Alphabet Inc. provides online advertising serv...
# Exchange                                                               NASDAQ
# Currency                                                                  USD
# Country                                                                   USA
# Sector                                                 Communication Services
# Industry                                       Internet Content & Information
# Address                     1600 Amphitheatre Parkway, Mountain View, CA, ...
# FullTimeEmployees                                                      135301
# ...

# %%
data_company_overview_FB = fd.get_company_overview("FB")
data_company_overview_FB[0].T
# Out:
#                                                                           NaN
# Symbol                                                                     FB
# AssetType                                                        Common Stock
# Name                                                            Facebook, Inc
# Description                 Facebook, Inc. develops products that enable p...
# Exchange                                                               NASDAQ
# Currency                                                                  USD
# Country                                                                   USA
# Sector                                                 Communication Services
# Industry                                       Internet Content & Information
# Address                     1601 Willow Road, Menlo Park, CA, United State...
# FullTimeEmployees                                                       58604
# ...
